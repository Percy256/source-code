# %%
import pandas as pd

# %%
df = pd.read_csv('D:\AI VIDEOS\AI ASSIGNMENT 4/laptop_price.csv', encoding = "cp1252")
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros
# 0      1339.69
# 1       898.94
# 2       575.00
# 3      2537.45
# 4      1803.60

# %%
import pandas as pd
import numpy as np
import random as rnd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
PROPS = {
    'boxprops':{'edgecolor':'black'},
    'medianprops':{'color':'black'},
    'whiskerprops':{'color':'black'},
    'capprops':{'color':'black'}
}

# %%
def plot_box(x, y, xlabel, ylabel, title, subtitle, color, title_position, subtitle_position, order=None):
    ax = sns.boxplot(data = df, y = y, x = x, order = order,
                 linewidth = 1.2, color = color, **PROPS,
                 flierprops = dict(marker = 'o', markeredgecolor = 'black', markersize = 6.5, linestyle = 'none', markerfacecolor = color, alpha = 0.9))
    plt.xlabel(xlabel, fontweight = 'bold', fontsize = 16)
    plt.ylabel(ylabel, fontweight = 'bold', fontsize = 16)
    ax.tick_params(labelsize = 14)
    ax.text(x = title_position, y = 1.07, s = title, fontsize = 22.5, weight = 'bold', ha = 'center', va = 'bottom', transform = ax.transAxes)
    ax.text(x = subtitle_position, y = 1.03, s = subtitle, fontsize = 16.5, alpha = 0.75, ha = 'center', va = 'bottom', transform = ax.transAxes)
    plt.show()

# %%
plot_box(x = "Price_euros", y = "Company", xlabel = 'Price (in Euro)', ylabel = "Laptop Manufacturer", title = "Laptop price by manufacturer",
         subtitle = "Distributions, boxplots", color = "lightskyblue", title_position = 0.22, subtitle_position = 0.112)

# %%
Object_columns = []
Numerical_columns = []
for column in df:
    if(df[column].dtypes == "object"):
        Object_columns.append(column)
        
    else:
        Numerical_columns.append(column)

# %%
Object_columns
# Out:
# ['Company',
#  'Product',
#  'TypeName',
#  'ScreenResolution',
#  'Cpu',
#  'Ram',
#  'Memory',
#  'Gpu',
#  'OpSys',
#  'Weight']

# %%
Numerical_columns
# Out:
# ['laptop_ID', 'Inches', 'Price_euros']

# %%
Object_df = df[Object_columns]

# %%
Object_df.head()
# Out:
#   Company      Product   TypeName                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook                            1440x900
# 2      HP       250 G6   Notebook                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1        Intel HD Graphics 6000  macOS  1.34kg
# 2         Intel HD Graphics 620  No OS  1.86kg
# 3            AMD Radeon Pro 455  macOS  1.83kg
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
Encoded_df = pd.DataFrame()

# %%
for column in Object_columns:
    encoded = encoder.fit_transform(df[column])
    Encoded_df[column] = encoded

# %%
Encoded_df.head()
# Out:
#    Company  Product  TypeName  ScreenResolution  Cpu  Ram  Memory  Gpu  OpSys  \
# 0        1      300         4                23   65    8       4   58      8
# 1        1      301         4                 1   63    8       2   51      8
# 2        7       50         3                 8   74    8      16   53      4
# 3        1      300         4                25   85    1      29    9      8
# 4        1      300         4                23   67    8      16   59      8
#
#    Weight
# 0      38
# 1      35
# 2      74
# 3      71
# 4      38

# %%
Merged_df = pd.concat([Encoded_df, df[Numerical_columns]], axis = 1)

# %%
Merged_df.head()
# Out:
#    Company  Product  TypeName  ScreenResolution  Cpu  Ram  Memory  Gpu  OpSys  \
# 0        1      300         4                23   65    8       4   58      8
# 1        1      301         4                 1   63    8       2   51      8
# 2        7       50         3                 8   74    8      16   53      4
# 3        1      300         4                25   85    1      29    9      8
# 4        1      300         4                23   67    8      16   59      8
#
#    Weight  laptop_ID  Inches  Price_euros
# 0      38          1    13.3      1339.69
# 1      35          2    13.3       898.94
# 2      74          3    15.6       575.00
# 3      71          4    15.4      2537.45
# 4      38          5    13.3      1803.60

# %%
corr = Merged_df.corr()

# %%
corr
# Out:
#                    Company   Product  TypeName  ScreenResolution       Cpu  \
# Company           1.000000  0.067234 -0.007718          0.094772  0.044593
# Product           0.067234  1.000000  0.065594          0.176393  0.143855
# TypeName         -0.007718  0.065594  1.000000         -0.175618 -0.128174
# ScreenResolution  0.094772  0.176393 -0.175618          1.000000  0.232751
# Cpu               0.044593  0.143855 -0.128174          0.232751  1.000000
# Ram              -0.008399  0.018305  0.213988          0.019858 -0.077176
# Memory            0.048086  0.088667  0.019091          0.059042 -0.013264
# Gpu               0.026537  0.094795 -0.204774          0.160816  0.490761
# OpSys             0.134290  0.120562  0.085223          0.070360  0.125374
# Weight           -0.159906 -0.204379 -0.211832         -0.218135  0.139861
# laptop_ID         0.106702  0.026869 -0.083170         -0.040251 -0.054633
# Inches           -0.085784 -0.218974 -0.077428         -0.247841  0.153041
# Price_euros       0.140371  0.139289 -0.127313          0.331327  0.529334
#
#                        Ram    Memory       Gpu     OpSys    Weight  laptop_ID  \
# Company          -0.008399  0.048086  0.026537  0.134290 -0.159906   0.106702
# Product           0.018305  0.088667  0.094795  0.120562 -0.204379   0.026869
# TypeName          0.213988  0.019091 -0.204774  0.085223 -0.211832  -0.083170
# ScreenResolution  0.019858  0.059042  0.160816  0.070360 -0.218135  -0.040251
# Cpu              -0.077176 -0.013264  0.490761  0.125374  0.139861  -0.054633
# Ram               1.000000 -0.248580 -0.138212  0.008627 -0.174577  -0.042326
# Memory           -0.248580  1.000000 -0.020784  0.035574 -0.218299   0.042962
# Gpu              -0.138212 -0.020784  1.000000  0.103853  0.274961  -0.006203
# OpSys             0.008627  0.035574  0.103853  1.000000 -0.031506   0.016616
# Weight           -0.174577 -0.218299  0.274961 -0.031506  1.000000  -0.040933
# laptop_ID        -0.042326  0.042962 -0.006203  0.016616 -0.040933   1.000000
# Inches           -0.149706 -0.193382  0.215710  0.034528  0.866304  -0.087796
# Price_euros      -0.254032  0.185680  0.443299  0.288911  0.030575   0.067830
#
#                     Inches  Price_euros
# Company          -0.085784     0.140371
# Product          -0.218974     0.139289
# TypeName         -0.077428    -0.127313
# ScreenResolution -0.247841     0.331327
# Cpu               0.153041     0.529334
# Ram              -0.149706    -0.254032
# Memory           -0.193382     0.185680
# Gpu               0.215710     0.443299
# OpSys             0.034528     0.288911
# Weight            0.866304     0.030575
# laptop_ID        -0.087796     0.067830
# Inches            1.000000     0.068197
# Price_euros       0.068197     1.000000

# %%
dataplot = sns.heatmap(corr, cmap="YlGnBu", annot=True)

# %%
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
yData = Merged_df["Price_euros"]

# %%
XData = Merged_df[Merged_df.columns[:-1]]

# %%
XData.head()
# Out:
#    Company  Product  TypeName  ScreenResolution  Cpu  Ram  Memory  Gpu  OpSys  \
# 0        1      300         4                23   65    8       4   58      8
# 1        1      301         4                 1   63    8       2   51      8
# 2        7       50         3                 8   74    8      16   53      4
# 3        1      300         4                25   85    1      29    9      8
# 4        1      300         4                23   67    8      16   59      8
#
#    Weight  laptop_ID  Inches
# 0      38          1    13.3
# 1      35          2    13.3
# 2      74          3    15.6
# 3      71          4    15.4
# 4      38          5    13.3

# %%
XData.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Company'}>,
#         <AxesSubplot:title={'center':'Product'}>,
#         <AxesSubplot:title={'center':'TypeName'}>],
#        [<AxesSubplot:title={'center':'ScreenResolution'}>,
#         <AxesSubplot:title={'center':'Cpu'}>,
#         <AxesSubplot:title={'center':'Ram'}>],
#        [<AxesSubplot:title={'center':'Memory'}>,
#         <AxesSubplot:title={'center':'Gpu'}>,
#         <AxesSubplot:title={'center':'OpSys'}>],
#        [<AxesSubplot:title={'center':'Weight'}>,
#         <AxesSubplot:title={'center':'laptop_ID'}>,
#         <AxesSubplot:title={'center':'Inches'}>]], dtype=object)

# %%
corr["Price_euros"].sort_values(ascending=False)
# Out:
# Price_euros         1.000000
# Cpu                 0.529334
# Gpu                 0.443299
# ScreenResolution    0.331327
# OpSys               0.288911
# Memory              0.185680
# Company             0.140371
# Product             0.139289
# Inches              0.068197
# laptop_ID           0.067830
# Weight              0.030575
# TypeName           -0.127313
# Ram                -0.254032
# Name: Price_euros, dtype: float64

# %%
Columns_With_High_Interest = ["Cpu", "Gpu", "ScreenResolution"]

# %%
sns.scatterplot(x = Merged_df["Cpu"], y = yData)
# Out:
# <AxesSubplot:xlabel='Cpu', ylabel='Price_euros'>

# %%
sns.scatterplot(x = Merged_df["Gpu"], y = yData)
# Out:
# <AxesSubplot:xlabel='Gpu', ylabel='Price_euros'>

# %%
sns.scatterplot(x = Merged_df["ScreenResolution"], y = yData)
# Out:
# <AxesSubplot:xlabel='ScreenResolution', ylabel='Price_euros'>

# %%
plot_box(x = "Price_euros", y = "Company", xlabel = 'Price (in Euro)', ylabel = "Laptop Manufacturer", title = "Laptop price by manufacturer",
         subtitle = "Distributions, boxplots", color = "Khaki", title_position = 0.22, subtitle_position = 0.112)

# %%
Merged_df.head()
# Out:
#    Company  Product  TypeName  ScreenResolution  Cpu  Ram  Memory  Gpu  OpSys  \
# 0        1      300         4                23   65    8       4   58      8
# 1        1      301         4                 1   63    8       2   51      8
# 2        7       50         3                 8   74    8      16   53      4
# 3        1      300         4                25   85    1      29    9      8
# 4        1      300         4                23   67    8      16   59      8
#
#    Weight  laptop_ID  Inches  Price_euros
# 0      38          1    13.3      1339.69
# 1      35          2    13.3       898.94
# 2      74          3    15.6       575.00
# 3      71          4    15.4      2537.45
# 4      38          5    13.3      1803.60

# %%
YData = Merged_df["Price_euros"]
XData = Merged_df[Merged_df.columns[:-1]]

# %%
from sklearn.model_selection import train_test_split

# %%
XData.head()
# Out:
#    Company  Product  TypeName  ScreenResolution  Cpu  Ram  Memory  Gpu  OpSys  \
# 0        1      300         4                23   65    8       4   58      8
# 1        1      301         4                 1   63    8       2   51      8
# 2        7       50         3                 8   74    8      16   53      4
# 3        1      300         4                25   85    1      29    9      8
# 4        1      300         4                23   67    8      16   59      8
#
#    Weight  laptop_ID  Inches
# 0      38          1    13.3
# 1      35          2    13.3
# 2      74          3    15.6
# 3      71          4    15.4
# 4      38          5    13.3

# %%
Xtrain,Xtest,ytrain,ytest = train_test_split(XData, YData)

# %%
ytrain.head()
# Out:
# 1111     769.15
# 545      705.50
# 403      879.00
# 885     1799.00
# 10       393.90
# Name: Price_euros, dtype: float64

# %%
ytrain.shape
# Out:
# (977,)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
forest = RandomForestRegressor().fit(Xtrain.values, ytrain.values)

# %%
forest.score(Xtrain, ytrain)
# Out:
# C:\Users\TREVOUR\anaconda3\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# 0.9764639109928891

# %%
forest.score(Xtest, ytest)
# Out:
# C:\Users\TREVOUR\anaconda3\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# 0.7906636574652542

# %%
predicted_test = forest.predict(Xtest)
# Out:
# C:\Users\TREVOUR\anaconda3\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
